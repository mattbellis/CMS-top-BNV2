# %%
import awkward as ak
import uproot

import numpy as np
import matplotlib.pylab as plt

import coffea

# %%
infilename = 'nano_ttsemilep_5k.root'

f = uproot.open(infilename)

f.keys()

# %%
ev = f['Events']

ev.keys()

# %%
ev['nPFCands'].array()

# %%
ev['nJetPFCands'].array()

# %%
ev['JetPFCands_pt'].array()

# %%
x = ev['JetPFCands_pFCandsIdx'].array()[0]

print(x)

for a in x:
    print(a)

# %%
x = ev['JetPFCands_pFCandsIdx']

ev['PF
